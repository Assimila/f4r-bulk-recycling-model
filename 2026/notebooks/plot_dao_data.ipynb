# %% [markdown]
# Extract data from a DAO NetCDF file

# %%
import numpy as np
import xarray as xr
import pandas as pd
import sys

# %%
#ds = xr.open_dataset("dao.80_93.nc")
ds = xr.open_dataset("/Users/ellendyer/Library/Mobile Documents/com~apple~CloudDocs/1SHARED_WORK/Work/3_ESA_GRANT/MODEL/data/dao.80_93.nc")
start = '1980-01-01'
end = '1993-09-30'
tspd = pd.date_range(start, end, freq='MS')
print(tspd)
ds['time'] = tspd
# Out:
# DatetimeIndex(['1980-01-01', '1980-02-01', '1980-03-01', '1980-04-01',
#                '1980-05-01', '1980-06-01', '1980-07-01', '1980-08-01',
#                '1980-09-01', '1980-10-01',
#                ...
#                '1992-12-01', '1993-01-01', '1993-02-01', '1993-03-01',
#                '1993-04-01', '1993-05-01', '1993-06-01', '1993-07-01',
#                '1993-08-01', '1993-09-01'],
#               dtype='datetime64[ns]', length=165, freq='MS')

# %%
if ds.coords["level"].isnull().all():
    print("Fixing broken pressure level data")
    levels = [1000.0, 950.0, 900.0, 850.0, 700.0, 500.0, 300.0, 200.0]
    ds.coords["level"] = xr.DataArray(levels, dims=["level"], coords={"level": levels}, attrs={"units": "hPa"})
# Out:
# Fixing broken pressure level data

# %%
# make sure lat runs from south to north
if not ds["lat"].to_index().is_monotonic_increasing:
    print("flipping lat")
    ds = ds.sortby("lat", ascending=True)
# Out:
# flipping lat

# %%
# make sure lon runs from west to east
if not ds["lon"].to_index().is_monotonic_increasing:
    print("flipping lon")
    ds = ds.sortby("lon", ascending=True)

# %%
# get a spatial subset 4°N–16°S, 50°–76°W
ds = ds.sel(lat=slice(-16, 4), lon=slice(-76, -50))

# %%
# make sure that the order of the dimensions is (lon, lat, ...) for all variables
ds = ds.transpose("lon", "lat", ...)

# %%
# grab the first time step
# should be Jan 1980
#ds = ds.isel(time=[6,7,8], drop=True)

ds = ds.isel(time=slice(0,60), drop=True)

def is_jja(month):
    return (month >= 6) & (month <= 8)
def is_son(month):
    return (month >= 9) & (month <= 11)
def is_jf(month):
    return (month >= 9) & (month <= 11)
def is_s(month):
    return (month==9)
def is_f(month):
    return (month==2)

ds = ds.sel(time=is_f(ds['time.month']),drop=True)
print(ds)
# Out:
# <xarray.Dataset> Size: 83kB
# Dimensions:  (lon: 14, lat: 11, time: 5, level: 8)
# Coordinates:
#   * time     (time) datetime64[ns] 40B 1980-02-01 1981-02-01 ... 1984-02-01
#   * lat      (lat) float32 44B -16.0 -14.0 -12.0 -10.0 -8.0 ... -2.0 0.0 2.0 4.0
#   * lon      (lon) float32 56B -76.0 -74.0 -72.0 -70.0 ... -54.0 -52.0 -50.0
#   * level    (level) float64 64B 1e+03 950.0 900.0 850.0 700.0 500.0 300.0 200.0
# Data variables:
#     Uwnd     (lon, lat, time, level) float32 25kB ...
#     Vwnd     (lon, lat, time, level) float32 25kB ...
#     Shum     (lon, lat, time, level) float32 25kB ...
#     Evap     (lon, lat, time) float32 3kB ...
#     Psfc     (lon, lat, time) float32 3kB ...
#     Prec     (lon, lat, time) float32 3kB ...
# Attributes:
#     creation_date:  Sat Dec 27 14:29:58 WAT 2008
#     Conventions:    None
#     title:          Sample

# %% [markdown]
# To integrate the column water vapor fluxes this notebook uses a basic method `integrate_no_extrapolation`.
#
# See below for a comparison between the DAO dataset precipitation (which is not used in the bulk recycling model) and modelled precipitation.
#
# An alternative method is `integrate_with_extrapolation`,
# which has been shown to produce modelled precipitation that has a slightly better agreement to the DAO dataset than `integrate_no_extrapolation`.
# The difference is small (~0.2 mm/day) compared to the RMSE of ~4.5 mm/day.
#
# If measurements of surface-level specific humidity and wind speeds are available, the method `integrate_with_surface_value` may offer an improvement.

# %%
import bulk_recycling_model.numerical_integration

# %%
# Integrate 10^-3 Shum Uwnd dp
# Because the integration limits are from high pressure to low pressure, we need to invert the sign.
integrand = -1 * 1e-3 * ds["Shum"] * ds["Uwnd"]
Fx = bulk_recycling_model.numerical_integration.integrate_no_extrapolation(integrand, ds["Psfc"])
# Units: mb x m/s

# %%
# Integrate 10^-3 Shum Vwnd dp
# Because the integration limits are from high pressure to low pressure, we need to invert the sign.
integrand = -1 * 1e-3 * ds["Shum"] * ds["Vwnd"]
Fy = bulk_recycling_model.numerical_integration.integrate_no_extrapolation(integrand, ds["Psfc"])
# Units: mb x m/s

# %% [markdown]
# some plots directly from xarray

# %%
ds["Evap"].mean('time').plot.pcolormesh(x="lon", y="lat")

# %%
ds["Prec"].mean('time').plot.pcolormesh(x="lon", y="lat")

# %%
xr.Dataset(
    {
        "Fx": Fx,
        "Fy": Fy,
    },
).mean('time').plot.quiver(
    x="lon",
    y="lat",
    u="Fx",
    v="Fy",
)

# %% [markdown]
# Prepare and scale the data

# %%
from bulk_recycling_model import preprocess
from bulk_recycling_model.axis import Axis
from bulk_recycling_model.scaling import Scaling, UnitSystem

# %%
# degrees
L = ds.coords["lon"].max().item() - ds.coords["lon"].min().item()
# convert to meters
L = L * 111e3 * np.cos(np.deg2rad(ds.coords["lat"].mean().item()))
dx = L / ds.sizes["lon"]

# %%
# lon axis
lon_axis = Axis(
    ds.coords["lon"].min().item(),
    ds.coords["lon"].diff("lon").mean().item(),
    ds.sizes["lon"],
)

# %%
# degrees
H = ds.coords["lat"].values[-1] - ds.coords["lat"].values[0]
# convert to meters
H = H * 111e3
dy = H / ds.sizes["lat"]

# %%
# lat axis
lat_axis = Axis(
    ds.coords["lat"].min().item(),
    ds.coords["lat"].diff("lat").mean().item(),
    ds.sizes["lat"],
)

# %%
print(f"{L = :.2e} m")
print(f"{dx = :.2e} m")
print(f"{H = :.2e} m")
print(f"{dy = :.2e} m")
# Out:
# L = 2.87e+06 m
# dx = 2.05e+05 m
# H = 2.22e+06 m
# dy = 2.02e+05 m

# %%
# make a scaling object to convert between unit systems
scaling = Scaling(H)

# %%
dx = scaling.distance.convert(dx, UnitSystem.SI, UnitSystem.scaled)
dy = scaling.distance.convert(dy, UnitSystem.SI, UnitSystem.scaled)
print(f"{dx = :.2e} scaled")
print(f"{dy = :.2e} scaled")
# Out:
# dx = 9.23e-02 scaled
# dy = 9.09e-02 scaled

# %%
# convert Fx and Fy to scaled units
Fx = scaling.water_vapor_flux.convert(Fx.values, UnitSystem.natural, UnitSystem.scaled)
Fy = scaling.water_vapor_flux.convert(Fy.values, UnitSystem.natural, UnitSystem.scaled)

# %%
# preprocess water vapor fluxes onto the secondary grid

Fx_left = np.empty((Fx.shape[0]-1,Fx.shape[1]-1,Fx.shape[2]))
Fx_right = np.empty((Fx.shape[0]-1,Fx.shape[1]-1,Fx.shape[2]))
Fy_bottom = np.empty((Fy.shape[0]-1,Fy.shape[1]-1,Fy.shape[2]))
Fy_top = np.empty((Fy.shape[0]-1,Fy.shape[1]-1,Fy.shape[2]))

for i,time in enumerate(ds.time):
    
    Fx_left[:,:,i] = preprocess.prepare_Fx_left(Fx[:,:,i])
    Fx_right[:,:,i] = preprocess.prepare_Fx_right(Fx[:,:,i])
    Fy_bottom[:,:,i] = preprocess.prepare_Fy_bottom(Fy[:,:,i])
    Fy_top[:,:,i] = preprocess.prepare_Fy_top(Fy[:,:,i])

# %%
# convert E to scaled units
E_scaled = scaling.evaporation.convert(ds["Evap"].values, UnitSystem.natural, UnitSystem.scaled)

# %%
# preprocess E onto the secondary grid
E = np.empty((E_scaled.shape[0]-1,E_scaled.shape[1]-1,E_scaled.shape[2]))

for i,time in enumerate(ds.time):
    E[:,:,i] = preprocess.prepare_E(E_scaled[:,:,i])

# %%
# compute P
P = np.empty((E.shape))

P = preprocess.calculate_precipitation(Fx_left, Fx_right, Fy_bottom, Fy_top, E, dx, dy)

# %% [markdown]
# plotting

# %%
import matplotlib.pyplot as plt

# %%
from bulk_recycling_model import plotting

# %%
Eplot = np.mean(E, axis=2)
fig, ax = plt.subplots()
collection = plotting.pcolormesh(ax, Eplot, lon_axis, lat_axis)
fig.colorbar(collection, label="E (scaled)")
fig.suptitle("Evaporation on the secondary grid")
# Out:
# Text(0.5, 0.98, 'Evaporation on the secondary grid')

# %%
#fig, ax = plt.subplots()
#collection = plotting.pcolormesh(ax, P, lon_axis, lat_axis,vmin=0.0,vmax=20.0)
#fig.colorbar(collection, label="P (scaled)")
#fig.suptitle("Calculated Precipitation")

Pplot = np.mean(P, axis=2)

fig, ax = plt.subplots()
cmap=plt.cm.viridis
cmap.set_extremes(over='yellow')
cmap.set_extremes(under='red')
    
collection = plotting.pcolormesh(ax, Pplot, lon_axis, lat_axis, 
                                     alpha=1,cmap=cmap,
                                     vmin=0.0,vmax=20.0)
contour = plotting.contour(ax, Pplot, lon_axis, lat_axis, colors='white',
                                     alpha=1,
                                     #linestyles='dotted',
                                     #negative_linestyles='solid',
                                     levels=[-4,-2,-1,0,2,4,8,10,20],
                                     )
ax.clabel(contour, contour.levels, fontsize=10)
fig.colorbar(collection, label="P (calculated)",extend='min')
plt.show()
plt.clf()
# Out:
# /Users/ellendyer/Documents/GitHub/f4r-bulk-recycling-model/bulk_recycling_model/plotting.py:79: UserWarning: The following kwargs were not used by contour: 'shading'
#   return ax.contour(X, Y, data, shading="nearest", **kwargs)

# %%
# get modelled P on the secondary grid
#modelled_P = preprocess.prepare_P(ds["Prec"].values)

modelled_P = np.empty((E_scaled.shape[0]-1,E_scaled.shape[1]-1,E_scaled.shape[2]))

for i,time in enumerate(ds.time):
    modelled_P[:,:,i] = preprocess.prepare_P(ds["Prec"][:,:,i].values)

# convert modelled P to scaled units
modelled_P = scaling.precipitation.convert(modelled_P, UnitSystem.natural, UnitSystem.scaled)

# %%
print(f"Modelled P has mean {modelled_P.mean()} and std {modelled_P.std()}")
print(f"Calculated P has mean {P.mean()} and std {P.std()}")
print(f"Comparing modelled and calculated precipitation RMSE: {np.sqrt(np.mean((P - modelled_P) ** 2))}")
# Out:
# Modelled P has mean 6.918401250013939 and std 2.968168509540912
# Calculated P has mean 7.599382952912866 and std 4.93192952214868
# Comparing modelled and calculated precipitation RMSE: 4.563589645963639

# %%
fig, ax = plt.subplots()
cmap=plt.cm.viridis
cmap.set_extremes(over='yellow')
cmap.set_extremes(under='red')

modelled_Pplot = np.mean(modelled_P, axis=2)
    
collection = plotting.pcolormesh(ax, modelled_Pplot, lon_axis, lat_axis, 
                                     alpha=1,cmap=cmap,
                                     vmin=0.0,vmax=20.0)
fig.colorbar(collection, label="P (secondary grid)",extend='min')
plt.show()
plt.clf()

# %%
# difference between modelled and calculated precipitation
fig, ax = plt.subplots()
cmap=plt.cm.BrBG
cmap.set_extremes(over='chartreuse')
cmap.set_extremes(under='black')
diff = Pplot - modelled_Pplot
collection = plotting.pcolormesh(ax, diff, lon_axis, lat_axis,vmin=-5,vmax=5,cmap=cmap)
fig.colorbar(collection, label="P (mm/day)",extend="both")
fig.suptitle("Difference between modelled and calculated precipitation")
# Out:
# Text(0.5, 0.98, 'Difference between modelled and calculated precipitation')

# %%
# Create a quiver plot

Fx_right_plot = np.mean(Fx_right, axis=2)
Fx_left_plot = np.mean(Fx_left, axis=2)
Fy_bottom_plot = np.mean(Fy_bottom, axis=2)
Fy_top_plot = np.mean(Fy_top, axis=2)

fig, ax = plt.subplots()
collection = plotting.pcolormesh(ax, Eplot, lon_axis, lat_axis, alpha=0.5)
fig.colorbar(collection, label="E (scaled)")
plotting.quiver(ax, Fx_left_plot, Fx_right_plot, Fy_bottom_plot, Fy_top_plot, lon_axis, lat_axis)
fig.suptitle("Evaporation + Water Vapor Fluxes on cell edges")
# Out:
# Text(0.5, 0.98, 'Evaporation + Water Vapor Fluxes on cell edges')
